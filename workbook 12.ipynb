# %% [markdown]
# # Workshop #2
# For the last 10 weeks, we have been covering various advance statistical techniques. In the final 5 weeks of the course, we will now focus on your original quantitative research project. Each week, you will need to complete a set of tasks. These tasks will help you move forward to completing the final paper.
#
# ## Tasks for Workshop #2: (Due 4/21/22)

# %% [markdown]
# <b>Write a Bibliography of three references related to your research question and mechanisms. Write the 3 references in American Sociological Association (ASA) Style. Write a 2-3 sentences summary of the each reference.</b>

# %% [markdown]
# <b>Frickel, Scott, and James R. Elliott. 2018. Sites Unseen: Uncovering Hidden Hazards in American Cities. Russel Sage.</b>
#
# Sites Unseen examines the redevelopment of hazardous sites over time. Hazardous sites consist sites that dealt with chemical toxics or produced industrial waste such as plastics factory, car garage, or dry cleaner. Regulation of land waste or pollution tied to land until 1980s. Their research found that 90% of the hazardous sites from 1956-2008 were converted to non-hazardous use such as residential, non-hazardous commercial use, etc... In the book they focus on case studies of Portland, New Orleans, Minneapolis, Philadelphia
#
# <b>Dillon, Lindsey. 2015. “War’s Remains: Slow Violence and the Urbanization of Military Bases in California.” Environmental Justice 8(1):1–5. doi: 10.1089/env.2014.0014.</b>
#
# O’Neil, Sandra George. 2007. “Superfund: Evaluating the Impact of Executive Order 12898.” Environmental Health Perspectives 115(7):1087–93. doi: 10.1289/ehp.9903.

# %% [markdown]
# <b>Conduct preliminary analysis of descriptive statistics. This can include correlation table, summary statistics table (with mean, standard deviation, minimum, median, and maximum), or frequency tables (either one variable or bi-variate).</b>

# %% [markdown]
# Figure 1: BRAC sites across the United States
# ![Layout.png](attachment:Layout.png)

# %% [markdown]
# <b>Write an abstract (~250 words).
# * The abstract MUST INCLUDE THE FOLLOWING:
#     * In the abstract include at least one sentence hooking the reader to the project.
#     * At least one sentence discussing the previous research OR mechanism/theory/concept you examine.
#     * Include a sentence mentioning the data set used.
#     * A sentence of hypothesis
#     * A sentence declaring your what you expect to find: “I expect to find ….”
#     * A sentence concluding what the results mean for either the literature or policy.
# * The abstract CAN include the following (but it isn’t necessary):
#     * A sentence with the research question</b>

# %% [markdown]
# The Pentagon has closed a total of 431 military installations across the United States and its territories, and 136 of them – almost one-third – have been reviewed as potential Superfund sites. The Environmental Protection Agency (EPA) designates specific polluted areas to be placed on the National Priority List, colloquially known as Superfund, and uses federal funds for significant long-term efforts to clean up contaminants and hazardous materials. Not all polluted sites are chosen for Superfund status however many industrial sites are in racial/ethnic minority and impoverished communities. The Department of Defense determines the location of military sites, and decommissioned military sites are likely to contribute to environmental damage. Yet, this federal agency and the relationship between military sites and Superfund sites remain understudied. I systematically examine federal environmental remediation efforts across decommissioned military installations (BRAC) in the United States.  I make a longtitudinal data through secondary data sources from the Govermental Accountability Office, the Environmental Protection Agency, the U.S. Census, and webscaping techniques. I expect my results will support my hypothesis that BRAC sites within white neighborhoods and higher-income communities are more likely to be chosen for the superfund program. This research will reveal the limitations to programs like Superfund to clean-up the military’s industrial legacy of environmental damage. Examining the hazardous cleanup and redevelopment of closed military bases reveals the role of the state in confronting climate and environmental crises, and its capacity to effectively restore the land, thereby initiating racial justice and environmental sustainability.
